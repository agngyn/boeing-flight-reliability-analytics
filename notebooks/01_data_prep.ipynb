# %% [markdown]
# # 01 – Data Prep: Load BTS & FAA, Enrich Flights
#
# This notebook:
# - Loads raw BTS CSV (Jan 2025 – Jan 2026)
# - Builds FAA aircraft lookup from MASTER.txt & ACFTREF.txt
# - Joins flights to aircraft info (manufacturer, model, family)
# - Saves `flights_enriched.parquet` for downstream analysis
